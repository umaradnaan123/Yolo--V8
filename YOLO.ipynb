# %%
# !nvidia-smi
# Out:
# Sat Jun 22 02:31:39 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source='/content/drive/MyDrive/PetImages/Cat/10002.jpg'
# Out:
# Ultralytics YOLOv8.2.38 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/drive/MyDrive/PetImages/Cat/10002.jpg: 608x640 1 person, 2 cats, 109.2ms
# Speed: 6.4ms preprocess, 109.2ms inference, 523.7ms postprocess per image at shape (1, 3, 608, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=val model=yolov8n.pt source='/content/drive/MyDrive/PetImages/Cat/10002.jpg'
# Out:
# WARNING ⚠️ 'data' argument is missing. Using default 'data=coco8.yaml'.
# Ultralytics YOLOv8.2.38 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# Dataset 'coco8.yaml' images not found ⚠️, missing path '/content/datasets/coco8/images/val'
# ...
# 100% 433k/433k [00:00<00:00, 27.8MB/s]
# Unzipping /content/datasets/coco8.zip to /content/datasets/coco8...: 100% 25/25 [00:00<00:00, 4862.62file/s]
# Dataset download success ✅ (1.2s), saved to /content/datasets
#
# ...
# 100% 755k/755k [00:00<00:00, 36.5MB/s]
# val: Scanning /content/datasets/coco8/labels/val... 4 images, 0 backgrounds, 0 corrupt: 100% 4/4 [00:00<00:00, 202.64it/s]
# val: New cache created: /content/datasets/coco8/labels/val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:02<00:00,  2.41s/it]
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt source='/content/drive/MyDrive/PetImages/Dog/10000.jpg'
# Out:
# WARNING ⚠️ 'data' argument is missing. Using default 'data=coco8.yaml'.
# Ultralytics YOLOv8.2.38 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=segment mode=predict model=yolov8n-seg.pt source='/content/drive/MyDrive/PetImages/Dog/100.jpg'
# Out:
# Ultralytics YOLOv8.2.38 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3404320 parameters, 0 gradients, 12.6 GFLOPs
#
# image 1/1 /content/drive/MyDrive/PetImages/Dog/100.jpg: 512x640 1 dog, 95.9ms
# Speed: 3.8ms preprocess, 95.9ms inference, 598.6ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to runs/segment/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=segment mode=val model=yolov8n-seg.pt source='/content/drive/MyDrive/PetImages/Dog/100.jpg'
# Out:
# WARNING ⚠️ 'data' argument is missing. Using default 'data=coco8-seg.yaml'.
# Ultralytics YOLOv8.2.38 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3404320 parameters, 0 gradients, 12.6 GFLOPs
#
# Dataset 'coco8-seg.yaml' images not found ⚠️, missing path '/content/datasets/coco8-seg/images/val'
# ...
# 100% 439k/439k [00:00<00:00, 28.8MB/s]
# Unzipping /content/datasets/coco8-seg.zip to /content/datasets/coco8-seg...: 100% 25/25 [00:00<00:00, 4526.36file/s]
# Dataset download success ✅ (1.3s), saved to /content/datasets
#
# val: Scanning /content/datasets/coco8-seg/labels/val... 4 images, 0 backgrounds, 0 corrupt: 100% 4/4 [00:00<00:00, 692.33it/s]
# val: New cache created: /content/datasets/coco8-seg/labels/val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.15it/s]
# ...

# %%
# !yolo task=segment mode=train model=yolov8n-seg.pt source='/content/drive/MyDrive/PetImages/Dog/100.jpg'
# Out:
# WARNING ⚠️ 'data' argument is missing. Using default 'data=coco8-seg.yaml'.
# Ultralytics YOLOv8.2.38 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=classify mode=predict model=yolov8n-cls.pt source='/content/drive/MyDrive/PetImages/Dog/100.jpg'
# Out:
# ...
# 100% 5.30M/5.30M [00:00<00:00, 170MB/s]
# Ultralytics YOLOv8.2.38 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 2715880 parameters, 0 gradients, 4.3 GFLOPs
#
# image 1/1 /content/drive/MyDrive/PetImages/Dog/100.jpg: 224x224 redbone 0.40, Rhodesian_ridgeback 0.38, Irish_terrier 0.09, golden_retriever 0.02, American_Staffordshire_terrier 0.02, 3.7ms
# Speed: 27.6ms preprocess, 3.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=classify mode=val model=yolov8n-cls.pt source='/content/drive/MyDrive/PetImages/Dog/100.jpg'
# Out:
# WARNING ⚠️ 'data' argument is missing. Using default 'data=imagenet10'.
# Ultralytics YOLOv8.2.38 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 2715880 parameters, 0 gradients, 4.3 GFLOPs
#
# Dataset not found ⚠️, missing path /content/datasets/imagenet10, attempting download...
# ...
# 100% 71.1k/71.1k [00:00<00:00, 11.7MB/s]
# Unzipping /content/datasets/imagenet10.zip to /content/datasets/imagenet10...: 100% 24/24 [00:00<00:00, 3366.55file/s]
# Dataset download success ✅ (0.9s), saved to /content/datasets/imagenet10
#
# train: /content/datasets/imagenet10/train... found 12 images in 10 classes ✅
# val: /content/datasets/imagenet10/val... found 12 images in 10 classes ✅
# test: None...
# val: Scanning /content/datasets/imagenet10/val... 12 images, 0 corrupt: 100% 12/12 [00:00<00:00, 1838.60it/s]
# val: New cache created: /content/datasets/imagenet10/val.cache
# ...

# %%
# !yolo task=classify mode=train model=yolov8n-cls.pt source='/content/drive/MyDrive/PetImages/Dog/100.jpg'
# Out:
# WARNING ⚠️ 'data' argument is missing. Using default 'data=imagenet10'.
# Ultralytics YOLOv8.2.38 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.yaml")
model = YOLO("yolov8n.pt")


model.train(data="coco8.yaml", epochs=3)
metrics = model.val()
path = model.export(format="onnx")
# Out:
# Ultralytics YOLOv8.2.38 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
